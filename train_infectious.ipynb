# %%
import numpy as np
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import os
import tensorflow as tf
from tqdm import tqdm
import requests
import json
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_log_error

from datetime import datetime
from datetime import timedelta

from tensorflow.keras import layers
from tensorflow.keras import Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()


for dirname, _, filenames in os.walk('./input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ./input/covid19countryinfo.csv
# ./input/SIR_data.csv
# ./input/states-daily.csv
# ./input/covid19-deepscore.csv
# ./input/population_data.csv
# ./input/full-list-total-tests-for-covid-19.csv
# ./input/country_codes.csv
# ./input/enriched_covid_19_week_2.csv
# ./input/covid19-global-forecasting-week-3/test.csv
# ./input/covid19-global-forecasting-week-3/submission.csv
# ./input/covid19-global-forecasting-week-3/train.csv
# ./input/korea/SeoulFloating.csv
# ./input/korea/TimeAge.csv
# ./input/korea/SearchTrend.csv
# ./input/korea/TimeProvince.csv
# ./input/korea/Weather.csv
# ./input/korea/PatientRoute.csv
# ./input/korea/PatientInfo.csv
# ./input/korea/Region.csv
# ./input/korea/TimeGender.csv
# ./input/korea/Case.csv
# ./input/korea/Time.csv
# ./input/covid19-global-forecasting-week-2/test.csv
# ./input/covid19-global-forecasting-week-2/submission.csv
# ./input/covid19-global-forecasting-week-2/train.csv
# ./input/covidAPI/ESP.json
# ./input/covidAPI/ICL.json
# ./input/covidAPI/CHN.json
# ./input/covidAPI/FRA.json
# ./input/covidAPI/THA.json
# ./input/covidAPI/DNK.json
# ./input/covidAPI/DEU.json
# ./input/covidAPI/KOR.json
# ./input/covidAPI/TWN.json
# ./input/covidAPI/ISL.json
# ./input/covidAPI/ITA.json
# ./input/.ipynb_checkpoints/SIR_data-checkpoint.csv
# ./input/.ipynb_checkpoints/covid19-deepscore-checkpoint.csv

# %%
train_df = pd.read_csv("./input/SIR_data.csv")
train_df.tail()
# Out:
#         Unnamed: 0           Code        Date     confirmed  confirmed_noise  \
# 119995         155  SIR-large-249  2020-07-05  6.813406e-09     8.345405e-09
# 119996         156  SIR-large-249  2020-07-06  3.576303e-09     3.202185e-09
# 119997         157  SIR-large-249  2020-07-07  1.854928e-09     1.278237e-09
# 119998         158  SIR-large-249  2020-07-08  9.504876e-10     1.032974e-09
# 119999         159  SIR-large-249  2020-07-09  4.810533e-10     6.917720e-10
#
#         infectious_noise_rate  infectious_rate      removed  removed_noise  \
# 119995           4.172703e-14     3.406703e-14  1744.099053    1744.099053
# 119996           1.601093e-14     1.788151e-14  1744.099053    1744.099053
# 119997           6.391185e-15     9.274641e-15  1744.099053    1744.099053
# 119998           5.164868e-15     4.752438e-15  1744.099053    1744.099053
# 119999           3.458860e-15     2.405266e-15  1744.099053    1744.099053
#
#         removed_noise_rate  removed_rate    susceptible  susceptible_noise  \
# 119995             0.00872       0.00872  198255.900947      198255.900947
# 119996             0.00872       0.00872  198255.900947      198255.900947
# 119997             0.00872       0.00872  198255.900947      198255.900947
# 119998             0.00872       0.00872  198255.900947      198255.900947
# 119999             0.00872       0.00872  198255.900947      198255.900947
#
#         susceptible_noise_rate  susceptible_rate
# 119995                 0.99128           0.99128
# 119996                 0.99128           0.99128
# 119997                 0.99128           0.99128
# 119998                 0.99128           0.99128
# 119999                 0.99128           0.99128

# %%
days_in_sequence = 21
output_days = 7

sequence_length = days_in_sequence - 1
training_percentage = 0.9
temp_dim = 2 # infectious and suspicious

# %%
#temporal input branch
temporal_input_layer = Input(shape=(sequence_length,temp_dim))
main_rnn_layer = layers.LSTM(64, return_sequences=True, recurrent_dropout=0.2)(temporal_input_layer)

#cases output branch
rnn_c = layers.LSTM(32)(main_rnn_layer)
dense_c = layers.Dense(16)(rnn_c)
dropout_c = layers.Dropout(0.2)(dense_c)
output_c = layers.Dense(7)(dropout_c) #activation=layers.LeakyReLU(alpha=0.1)
cases = layers.LeakyReLU(alpha=0.1,name="infectious")(output_c)

model = Model([temporal_input_layer], [cases])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 20, 2)             0
# _________________________________________________________________
# lstm (LSTM)                  (None, 20, 64)            17152
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dense (Dense)                (None, 16)                528
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 119
# _________________________________________________________________
# infectious (LeakyReLU)       (None, 7)                 0
# =================================================================
# Total params: 30,215
# Trainable params: 30,215
# Non-trainable params: 0
# _________________________________________________________________

# %%
callbacks = [ReduceLROnPlateau(monitor='val_loss', verbose=1, factor=0.6), #patience=4  #EarlyStopping(monitor='val_loss', patience=20)
             ModelCheckpoint(filepath='best_infectious_model.h5', monitor='val_loss', save_best_only=True)]
model.compile(loss=[tf.keras.losses.mean_squared_logarithmic_error], optimizer="adam")

# %%
# Creating train input from DataFrames No Noise
# train_country = ["KOR", "TWA", "THA", "ITA", "ISL", "DNK"]
# train_df = train_df.query("Code in {}".format(train_country))

trend_list = []

# for code in train_df.Code.unique():
for i in range(250):
    code = "SIR-small-{}".format(i)
    country_df = train_df.query(f"Code=='{code}'")
    # Added a quick hack to double the number of sequences
    # Warning: This will later create a minor leakage from the training set into the validation set.
    for i in range(0,len(country_df),int(days_in_sequence/2)):
        if i+days_in_sequence<=len(country_df):
            
            #prepare rate inputs, use rates with noise
            infectious_rate_trend = [float(x) for x in country_df[i:i+days_in_sequence-1].infectious_rate]
            susceptible_rate_trend = [float(x) for x in country_df[i:i+days_in_sequence-1].susceptible_rate] 

            #prepare outputs, use original rates
            expected_infectious_rate = [float(x) for x in country_df.iloc[i+days_in_sequence-1:i+days_in_sequence-1+output_days].infectious_rate]

            trend_list.append({ "infectious_rate_trend":infectious_rate_trend,
                                "susceptible_rate_trend":susceptible_rate_trend,
                                "expected_infectious_rate":expected_infectious_rate})
trend_df = pd.DataFrame(trend_list)

trend_df["temporal_inputs"] = [np.asarray([trends["infectious_rate_trend"], trends["susceptible_rate_trend"]]) for idx,trends in trend_df.iterrows()]

trend_df = shuffle(trend_df)

training_item_count = int(len(trend_df)*training_percentage)
validation_item_count = len(trend_df)-int(len(trend_df)*training_percentage)
training_df = trend_df[:training_item_count]
validation_df = trend_df[training_item_count:]

X_temporal_train = np.asarray(np.transpose(np.reshape(np.asarray([np.asarray(x) for x in training_df["temporal_inputs"].values]),(training_item_count,temp_dim,sequence_length)),(0,2,1) )).astype(np.float32)
Y_cases_train = np.asarray([np.asarray(x) for x in training_df["expected_infectious_rate"]]).astype(np.float32)

X_temporal_test = np.asarray(np.transpose(np.reshape(np.asarray([np.asarray(x) for x in validation_df["temporal_inputs"]]),(validation_item_count,temp_dim,sequence_length)),(0,2,1)) ).astype(np.float32)
Y_cases_test = np.asarray([np.asarray(x) for x in validation_df["expected_infectious_rate"]]).astype(np.float32)

# %%
history = model.fit([X_temporal_train], [Y_cases_train], 
          epochs = 50, 
          batch_size = 16, 
          validation_data=([X_temporal_test],  [Y_cases_test]), 
          callbacks=callbacks)
loss = history.history['loss']
val_loss = history.history['val_loss']
# Out:
# Train on 3150 samples, validate on 350 samples
# Epoch 1/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 1.8749e-04 - val_loss: 2.5714e-04
# Epoch 2/50
# 3150/3150 [==============================] - 7s 2ms/step - loss: 1.8008e-04 - val_loss: 2.5714e-04
# Epoch 3/50
# 3150/3150 [==============================] - 7s 2ms/step - loss: 1.7935e-04 - val_loss: 2.5714e-04
# Epoch 4/50
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.7683e-04 - val_loss: 2.3035e-04
# Epoch 5/50
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.7451e-04 - val_loss: 2.3796e-04
# Epoch 6/50
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.5999e-04 - val_loss: 1.9391e-04
# Epoch 7/50
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.1851e-04 - val_loss: 7.6627e-05
# Epoch 8/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.4416e-05 - val_loss: 3.0445e-05
# Epoch 9/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.6291e-05 - val_loss: 1.5263e-05
# Epoch 10/50
# 3150/3150 [==============================] - 11s 3ms/step - loss: 2.1721e-05 - val_loss: 1.1474e-05
# Epoch 11/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 1.4516e-05 - val_loss: 1.3199e-05
# Epoch 12/50
# 3150/3150 [==============================] - 10s 3ms/step - loss: 1.5414e-05 - val_loss: 1.1141e-05
# Epoch 13/50
# 3150/3150 [==============================] - 10s 3ms/step - loss: 1.2669e-05 - val_loss: 9.6933e-06
# Epoch 14/50
# 3150/3150 [==============================] - 11s 3ms/step - loss: 1.1929e-05 - val_loss: 5.3233e-06
# Epoch 15/50
# 3150/3150 [==============================] - 12s 4ms/step - loss: 1.0973e-05 - val_loss: 5.1195e-06
# Epoch 16/50
# 3150/3150 [==============================] - 10s 3ms/step - loss: 1.0684e-05 - val_loss: 6.9293e-06
# Epoch 17/50
# 3136/3150 [============================>.] - ETA: 0s - loss: 9.3053e-06
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# 3150/3150 [==============================] - 10s 3ms/step - loss: 9.2770e-06 - val_loss: 6.0963e-06
# Epoch 18/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 8.5090e-06 - val_loss: 6.7314e-06
# Epoch 19/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 7.3220e-06 - val_loss: 4.5321e-06
# Epoch 20/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 8.2662e-06 - val_loss: 1.0002e-05
# Epoch 21/50
# 3150/3150 [==============================] - 11s 3ms/step - loss: 7.3513e-06 - val_loss: 2.9370e-06
# Epoch 22/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 8.7397e-06 - val_loss: 2.8440e-06
# Epoch 23/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 9.6173e-06 - val_loss: 4.8529e-06
# Epoch 24/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 7.5105e-06 - val_loss: 3.1767e-06
# Epoch 25/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 9.3611e-06 - val_loss: 3.6483e-06
# Epoch 26/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 8.3659e-06 - val_loss: 2.4163e-06
# Epoch 27/50
# 3136/3150 [============================>.] - ETA: 0s - loss: 7.2637e-06
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
# 3150/3150 [==============================] - 9s 3ms/step - loss: 7.2912e-06 - val_loss: 5.0410e-06
# Epoch 28/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 6.4958e-06 - val_loss: 3.7792e-06
# Epoch 29/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.7869e-06 - val_loss: 4.7041e-06
# Epoch 30/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.7645e-06 - val_loss: 2.7904e-06
# Epoch 31/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.9470e-06 - val_loss: 2.9166e-06
# Epoch 32/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 6.1820e-06 - val_loss: 4.7535e-06
# Epoch 33/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6946e-06 - val_loss: 3.0172e-06
# Epoch 34/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 6.7289e-06 - val_loss: 3.5900e-06
# Epoch 35/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 6.0445e-06 - val_loss: 1.8629e-06
# Epoch 36/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 7.9641e-06 - val_loss: 1.7785e-06
# Epoch 37/50
# 3136/3150 [============================>.] - ETA: 0s - loss: 6.1552e-06
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
# 3150/3150 [==============================] - 9s 3ms/step - loss: 6.1297e-06 - val_loss: 1.9653e-06
# Epoch 38/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.0052e-06 - val_loss: 2.3500e-06
# Epoch 39/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.5601e-06 - val_loss: 1.9113e-06
# Epoch 40/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.2405e-06 - val_loss: 2.9555e-06
# Epoch 41/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.2114e-06 - val_loss: 2.4770e-06
# Epoch 42/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6443e-06 - val_loss: 1.7104e-06
# Epoch 43/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.5646e-06 - val_loss: 3.2508e-06
# Epoch 44/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.3747e-06 - val_loss: 5.9205e-06
# Epoch 45/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6171e-06 - val_loss: 2.1660e-06
# Epoch 46/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.5471e-06 - val_loss: 4.5696e-06
# Epoch 47/50
# 3120/3150 [============================>.] - ETA: 0s - loss: 4.8422e-06
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.8077e-06 - val_loss: 1.7161e-06
# Epoch 48/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.6084e-06 - val_loss: 1.8681e-06
# Epoch 49/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.7514e-06 - val_loss: 1.5549e-06
# Epoch 50/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.1101e-06 - val_loss: 2.0876e-06

# %%
# Creating train input from DataFrames Small Noise
# train_country = ["KOR", "TWA", "THA", "ITA", "ISL", "DNK"]
# train_df = train_df.query("Code in {}".format(train_country))
days_in_sequence = 21
output_days = 7

trend_list = []

# for code in train_df.Code.unique():
for i in range(250):
    code = "SIR-small-{}".format(i)
    country_df = train_df.query(f"Code=='{code}'")
    # Added a quick hack to double the number of sequences
    # Warning: This will later create a minor leakage from the training set into the validation set.
    for i in range(0,len(country_df),int(days_in_sequence/2)):
        if i+days_in_sequence<=len(country_df):
            
            #prepare rate inputs, use rates with noise
            infectious_rate_trend = [float(x) for x in country_df[i:i+days_in_sequence-1].infectious_noise_rate]
            susceptible_rate_trend = [float(x) for x in country_df[i:i+days_in_sequence-1].susceptible_noise_rate] 

            #prepare outputs, use original rates
            expected_infectious_rate = [float(x) for x in country_df.iloc[i+days_in_sequence-1:i+days_in_sequence-1+output_days].infectious_rate]
            
            trend_list.append({ "infectious_rate_trend":infectious_rate_trend,
                                "susceptible_rate_trend":susceptible_rate_trend,
                                "expected_infectious_rate":expected_infectious_rate})
trend_df = pd.DataFrame(trend_list)

trend_df["temporal_inputs"] = [np.asarray([trends["infectious_rate_trend"], trends["susceptible_rate_trend"]]) for idx,trends in trend_df.iterrows()]

trend_df = shuffle(trend_df)

training_item_count = int(len(trend_df)*training_percentage)
validation_item_count = len(trend_df)-int(len(trend_df)*training_percentage)
training_df = trend_df[:training_item_count]
validation_df = trend_df[training_item_count:]

X_temporal_train = np.asarray(np.transpose(np.reshape(np.asarray([np.asarray(x) for x in training_df["temporal_inputs"].values]),(training_item_count,temp_dim,sequence_length)),(0,2,1) )).astype(np.float32)
Y_cases_train = np.asarray([np.asarray(x) for x in training_df["expected_infectious_rate"]]).astype(np.float32)

X_temporal_test = np.asarray(np.transpose(np.reshape(np.asarray([np.asarray(x) for x in validation_df["temporal_inputs"]]),(validation_item_count,temp_dim,sequence_length)),(0,2,1)) ).astype(np.float32)
Y_cases_test = np.asarray([np.asarray(x) for x in validation_df["expected_infectious_rate"]]).astype(np.float32)

# %%
history = model.fit([X_temporal_train], [Y_cases_train], 
          initial_epoch=50,
          epochs = 100,  
          batch_size = 16, 
          validation_data=([X_temporal_test],  [Y_cases_test]), 
          callbacks=callbacks)
loss.extend(history.history['loss'])
val_loss.extend(history.history['val_loss'])
# Out:
# Train on 3150 samples, validate on 350 samples
# Epoch 51/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.8637e-06 - val_loss: 2.2064e-06
# Epoch 52/100
# 3150/3150 [==============================] - 11s 3ms/step - loss: 4.8261e-06 - val_loss: 2.1368e-06
# Epoch 53/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.1480e-06 - val_loss: 3.3464e-06
# Epoch 54/100
# 3150/3150 [==============================] - 10s 3ms/step - loss: 4.7980e-06 - val_loss: 2.1892e-06
# Epoch 55/100
# 3150/3150 [==============================] - 12s 4ms/step - loss: 5.8974e-06 - val_loss: 2.1523e-06
# Epoch 56/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.1041e-06 - val_loss: 2.2236e-06
# Epoch 57/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.4973e-06 - val_loss: 2.0815e-06
# Epoch 58/100
# 3150/3150 [==============================] - 10s 3ms/step - loss: 5.1156e-06 - val_loss: 3.1480e-06
# Epoch 59/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.4982e-06 - val_loss: 1.8077e-06
# Epoch 60/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.4274e-06 - val_loss: 2.2899e-06
# Epoch 61/100
# 3136/3150 [============================>.] - ETA: 0s - loss: 4.5500e-06
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 7.775999838486313e-05.
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.5350e-06 - val_loss: 3.7098e-06
# Epoch 62/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.5733e-06 - val_loss: 3.4242e-06
# Epoch 63/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.5582e-06 - val_loss: 2.2399e-06
# Epoch 64/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.3170e-06 - val_loss: 2.7256e-06
# Epoch 65/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6168e-06 - val_loss: 1.7518e-06
# Epoch 66/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.0299e-06 - val_loss: 2.2775e-06
# Epoch 67/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6424e-06 - val_loss: 1.6511e-06
# Epoch 68/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.8873e-06 - val_loss: 1.7814e-06
# Epoch 69/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.2539e-06 - val_loss: 1.9802e-06
# Epoch 70/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.9572e-06 - val_loss: 3.0450e-06
# Epoch 71/100
# 3120/3150 [============================>.] - ETA: 0s - loss: 5.6106e-06
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 4.6655999904032795e-05.
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.5687e-06 - val_loss: 1.6872e-06
# Epoch 72/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.4085e-06 - val_loss: 1.5501e-06
# Epoch 73/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6138e-06 - val_loss: 2.4543e-06
# Epoch 74/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.7307e-06 - val_loss: 1.6584e-06
# Epoch 75/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.5674e-06 - val_loss: 1.9235e-06
# Epoch 76/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.4450e-06 - val_loss: 1.9082e-06
# Epoch 77/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.6411e-06 - val_loss: 1.5763e-06
# Epoch 78/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.3610e-06 - val_loss: 1.8058e-06
# Epoch 79/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.7675e-06 - val_loss: 1.6307e-06
# Epoch 80/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.4501e-06 - val_loss: 1.7759e-06
# Epoch 81/100
# 3136/3150 [============================>.] - ETA: 0s - loss: 4.1285e-06
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 2.799360081553459e-05.
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.1123e-06 - val_loss: 1.6925e-06
# Epoch 82/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.3788e-06 - val_loss: 1.9047e-06
# Epoch 83/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.1742e-06 - val_loss: 1.7241e-06
# Epoch 84/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.0356e-06 - val_loss: 2.0454e-06
# Epoch 85/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.1827e-06 - val_loss: 2.2174e-06
# Epoch 86/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.0450e-06 - val_loss: 1.8957e-06
# Epoch 87/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.7469e-06 - val_loss: 1.8435e-06
# Epoch 88/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.3980e-06 - val_loss: 1.6432e-06
# Epoch 89/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.7480e-06 - val_loss: 1.8849e-06
# Epoch 90/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.3575e-06 - val_loss: 1.6491e-06
# Epoch 91/100
# 3120/3150 [============================>.] - ETA: 0s - loss: 4.6931e-06
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 1.6796160707599483e-05.
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6617e-06 - val_loss: 1.5287e-06
# Epoch 92/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.6236e-06 - val_loss: 1.6271e-06
# Epoch 93/100
# 3150/3150 [==============================] - 10s 3ms/step - loss: 4.8863e-06 - val_loss: 1.5711e-06
# Epoch 94/100
# 3150/3150 [==============================] - 12s 4ms/step - loss: 5.2327e-06 - val_loss: 1.5939e-06
# Epoch 95/100
# 3150/3150 [==============================] - 10s 3ms/step - loss: 4.1398e-06 - val_loss: 1.5775e-06
# Epoch 96/100
# 3150/3150 [==============================] - 8s 3ms/step - loss: 4.0393e-06 - val_loss: 1.7770e-06
# Epoch 97/100
# 3150/3150 [==============================] - 8s 3ms/step - loss: 4.1773e-06 - val_loss: 1.6569e-06
# Epoch 98/100
# 3150/3150 [==============================] - 8s 3ms/step - loss: 3.8374e-06 - val_loss: 1.8636e-06
# Epoch 99/100
# 3150/3150 [==============================] - 8s 3ms/step - loss: 4.0881e-06 - val_loss: 1.5355e-06
# Epoch 100/100
# 3150/3150 [==============================] - 8s 3ms/step - loss: 4.3235e-06 - val_loss: 1.6044e-06

# %%
# Create middle noise data
days_in_sequence = 21
output_days = 7

trend_list = []

# for code in train_df.Code.unique():
for i in range(250):
    code = "SIR-middle-{}".format(i)
    country_df = train_df.query(f"Code=='{code}'")
    # Added a quick hack to double the number of sequences
    # Warning: This will later create a minor leakage from the training set into the validation set.
    for i in range(0,len(country_df),int(days_in_sequence/2)):
        if i+days_in_sequence<=len(country_df):
            
            #prepare rate inputs, use rates with noise
            infectious_rate_trend = [float(x) for x in country_df[i:i+days_in_sequence-1].infectious_noise_rate]
            susceptible_rate_trend = [float(x) for x in country_df[i:i+days_in_sequence-1].susceptible_noise_rate] 

            #prepare outputs, use original rates
            expected_infectious_rate = [float(x) for x in country_df.iloc[i+days_in_sequence-1:i+days_in_sequence-1+output_days].infectious_rate]

            trend_list.append({ "infectious_rate_trend":infectious_rate_trend,
                                "susceptible_rate_trend":susceptible_rate_trend,
                                "expected_infectious_rate":expected_infectious_rate})
trend_df = pd.DataFrame(trend_list)

trend_df["temporal_inputs"] = [np.asarray([trends["infectious_rate_trend"], trends["susceptible_rate_trend"]]) for idx,trends in trend_df.iterrows()]

trend_df = shuffle(trend_df)
print(len(trend_df))
trend_df.head()

training_item_count = int(len(trend_df)*training_percentage)
validation_item_count = len(trend_df)-int(len(trend_df)*training_percentage)
training_df = trend_df[:training_item_count]
validation_df = trend_df[training_item_count:]

X_temporal_train = np.asarray(np.transpose(np.reshape(np.asarray([np.asarray(x) for x in training_df["temporal_inputs"].values]),(training_item_count,temp_dim,sequence_length)),(0,2,1) )).astype(np.float32)
Y_cases_train = np.asarray([np.asarray(x) for x in training_df["expected_infectious_rate"]]).astype(np.float32)

X_temporal_test = np.asarray(np.transpose(np.reshape(np.asarray([np.asarray(x) for x in validation_df["temporal_inputs"]]),(validation_item_count,temp_dim,sequence_length)),(0,2,1)) ).astype(np.float32)
Y_cases_test = np.asarray([np.asarray(x) for x in validation_df["expected_infectious_rate"]]).astype(np.float32)
# Out:
# 3500

# %%
history = model.fit([X_temporal_train], [Y_cases_train],
          initial_epoch=100,
          epochs = 150, 
          batch_size = 16, 
          validation_data=([X_temporal_test],  [Y_cases_test]), 
          callbacks=callbacks)
loss.extend(history.history['loss'])
val_loss.extend(history.history['val_loss'])
# Out:
# Train on 3150 samples, validate on 350 samples
# Epoch 101/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.5715e-06 - val_loss: 2.3597e-06
# Epoch 102/150
# 3150/3150 [==============================] - 10s 3ms/step - loss: 5.6543e-06 - val_loss: 2.2618e-06
# Epoch 103/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.4853e-06 - val_loss: 2.2658e-06
# Epoch 104/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.2081e-06 - val_loss: 2.3982e-06
# Epoch 105/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.3691e-06 - val_loss: 2.1978e-06
# Epoch 106/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 4.7348e-06 - val_loss: 2.3678e-06
# Epoch 107/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.1370e-06 - val_loss: 2.2402e-06
# Epoch 108/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.0522e-06 - val_loss: 2.0412e-06
# Epoch 109/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 4.6778e-06 - val_loss: 2.0851e-06
# Epoch 110/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.2563e-06 - val_loss: 2.0505e-06
# Epoch 111/150
# 3136/3150 [============================>.] - ETA: 0s - loss: 4.3390e-06
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 1.007769642455969e-05.
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.1070e-06 - val_loss: 2.0195e-06
# Epoch 112/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 4.7269e-06 - val_loss: 1.9915e-06
# Epoch 113/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 4.1849e-06 - val_loss: 1.9631e-06
# Epoch 114/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 4.4345e-06 - val_loss: 1.9813e-06
# Epoch 115/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 4.2273e-06 - val_loss: 1.9543e-06
# Epoch 116/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 3.8778e-06 - val_loss: 1.9322e-06
# Epoch 117/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 4.1463e-06 - val_loss: 1.9611e-06
# Epoch 118/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 4.3796e-06 - val_loss: 1.9293e-06
# Epoch 119/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 4.3545e-06 - val_loss: 1.9239e-06
# Epoch 120/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 4.1346e-06 - val_loss: 1.9632e-06
# Epoch 121/150
# 3120/3150 [============================>.] - ETA: 0s - loss: 4.8888e-06
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 6.046617636457085e-06.
# 3150/3150 [==============================] - 8s 2ms/step - loss: 4.9869e-06 - val_loss: 2.0180e-06
# Epoch 122/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 4.5685e-06 - val_loss: 1.9199e-06
# Epoch 123/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 4.4633e-06 - val_loss: 1.8910e-06
# Epoch 124/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 4.2074e-06 - val_loss: 1.8963e-06
# Epoch 125/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 4.3663e-06 - val_loss: 1.8765e-06
# Epoch 126/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 4.2214e-06 - val_loss: 1.8777e-06
# Epoch 127/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 4.1994e-06 - val_loss: 1.8701e-06
# Epoch 128/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 4.2073e-06 - val_loss: 1.8992e-06
# Epoch 129/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 3.9221e-06 - val_loss: 1.8641e-06
# Epoch 130/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 4.0229e-06 - val_loss: 1.8995e-06
# Epoch 131/150
# 3120/3150 [============================>.] - ETA: 0s - loss: 3.9599e-06
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 3.6279706364439334e-06.
# 3150/3150 [==============================] - 8s 2ms/step - loss: 4.0013e-06 - val_loss: 1.8598e-06
# Epoch 132/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 3.9709e-06 - val_loss: 1.8626e-06
# Epoch 133/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 4.2807e-06 - val_loss: 1.8536e-06
# Epoch 134/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 3.9338e-06 - val_loss: 1.8518e-06
# Epoch 135/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 4.3000e-06 - val_loss: 1.8463e-06
# Epoch 136/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 4.0229e-06 - val_loss: 1.8485e-06
# Epoch 137/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 3.9801e-06 - val_loss: 1.8470e-06
# Epoch 138/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 4.4937e-06 - val_loss: 1.8397e-06
# Epoch 139/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 4.4448e-06 - val_loss: 1.8606e-06
# Epoch 140/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 3.9834e-06 - val_loss: 1.8446e-06
# Epoch 141/150
# 3136/3150 [============================>.] - ETA: 0s - loss: 4.3399e-06
# Epoch 00141: ReduceLROnPlateau reducing learning rate to 2.1767824364360423e-06.
# 3150/3150 [==============================] - 8s 3ms/step - loss: 4.3364e-06 - val_loss: 1.8421e-06
# Epoch 142/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 4.0740e-06 - val_loss: 1.8372e-06
# Epoch 143/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 4.2806e-06 - val_loss: 1.8572e-06
# Epoch 144/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 4.5859e-06 - val_loss: 1.8350e-06
# Epoch 145/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 3.8971e-06 - val_loss: 1.8352e-06
# Epoch 146/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 4.6318e-06 - val_loss: 1.8332e-06
# Epoch 147/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 3.6935e-06 - val_loss: 1.8533e-06
# Epoch 148/150
# 3150/3150 [==============================] - 8s 2ms/step - loss: 3.9518e-06 - val_loss: 1.8312e-06
# Epoch 149/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 3.9729e-06 - val_loss: 1.8296e-06
# Epoch 150/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 4.2559e-06 - val_loss: 1.8348e-06

# %%
# Create large noise data
days_in_sequence = 21
output_days = 7

trend_list = []

# for code in train_df.Code.unique():
for i in range(250):
    code = "SIR-large-{}".format(i)
    country_df = train_df.query(f"Code=='{code}'")
    # Added a quick hack to double the number of sequences
    # Warning: This will later create a minor leakage from the training set into the validation set.
    for i in range(0,len(country_df),int(days_in_sequence/2)):
        if i+days_in_sequence<=len(country_df):
            
            #prepare rate inputs, use rates with noise
            infectious_rate_trend = [float(x) for x in country_df[i:i+days_in_sequence-1].infectious_noise_rate]
            susceptible_rate_trend = [float(x) for x in country_df[i:i+days_in_sequence-1].susceptible_noise_rate] 

            #prepare outputs, use original rates
            expected_infectious_rate = [float(x) for x in country_df.iloc[i+days_in_sequence-1:i+days_in_sequence-1+output_days].infectious_rate]

            trend_list.append({ "infectious_rate_trend":infectious_rate_trend,
                                "susceptible_rate_trend":susceptible_rate_trend,
                                "expected_infectious_rate":expected_infectious_rate})
trend_df = pd.DataFrame(trend_list)

trend_df["temporal_inputs"] = [np.asarray([trends["infectious_rate_trend"], trends["susceptible_rate_trend"]]) for idx,trends in trend_df.iterrows()]

trend_df = shuffle(trend_df)
print(len(trend_df))
trend_df.head()

training_item_count = int(len(trend_df)*training_percentage)
validation_item_count = len(trend_df)-int(len(trend_df)*training_percentage)
training_df = trend_df[:training_item_count]
validation_df = trend_df[training_item_count:]

X_temporal_train = np.asarray(np.transpose(np.reshape(np.asarray([np.asarray(x) for x in training_df["temporal_inputs"].values]),(training_item_count,temp_dim,sequence_length)),(0,2,1) )).astype(np.float32)
Y_cases_train = np.asarray([np.asarray(x) for x in training_df["expected_infectious_rate"]]).astype(np.float32)

X_temporal_test = np.asarray(np.transpose(np.reshape(np.asarray([np.asarray(x) for x in validation_df["temporal_inputs"]]),(validation_item_count,temp_dim,sequence_length)),(0,2,1)) ).astype(np.float32)
Y_cases_test = np.asarray([np.asarray(x) for x in validation_df["expected_infectious_rate"]]).astype(np.float32)
# Out:
# 3500

# %%
history = model.fit([X_temporal_train], [Y_cases_train],
          initial_epoch=150,
          epochs = 200, 
          batch_size = 16, 
          validation_data=([X_temporal_test],  [Y_cases_test]), 
          callbacks=callbacks)
loss.extend(history.history['loss'])
val_loss.extend(history.history['val_loss'])
# Out:
# Train on 3150 samples, validate on 350 samples
# Epoch 151/200
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.1671e-05 - val_loss: 1.3834e-05
# Epoch 152/200
# 3150/3150 [==============================] - 8s 3ms/step - loss: 1.1739e-05 - val_loss: 1.3739e-05
# Epoch 153/200
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.2170e-05 - val_loss: 1.3864e-05
# Epoch 154/200
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.1381e-05 - val_loss: 1.4013e-05
# Epoch 155/200
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.2273e-05 - val_loss: 1.4004e-05
# Epoch 156/200
# 3150/3150 [==============================] - 8s 3ms/step - loss: 1.1502e-05 - val_loss: 1.3997e-05
# Epoch 157/200
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.3162e-05 - val_loss: 1.4136e-05
# Epoch 158/200
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.1993e-05 - val_loss: 1.4108e-05
# Epoch 159/200
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.0716e-05 - val_loss: 1.4123e-05
# Epoch 160/200
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.1400e-05 - val_loss: 1.4110e-05
# Epoch 161/200
# 3120/3150 [============================>.] - ETA: 0s - loss: 1.2304e-05
# Epoch 00161: ReduceLROnPlateau reducing learning rate to 1.3060694072919432e-06.
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.2248e-05 - val_loss: 1.4186e-05
# Epoch 162/200
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.0971e-05 - val_loss: 1.4230e-05
# Epoch 163/200
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.1231e-05 - val_loss: 1.4296e-05
# Epoch 164/200
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.2375e-05 - val_loss: 1.4190e-05
# Epoch 165/200
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.2493e-05 - val_loss: 1.4101e-05
# Epoch 166/200
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.2727e-05 - val_loss: 1.4056e-05
# Epoch 167/200
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.2652e-05 - val_loss: 1.4088e-05
# Epoch 168/200
# 3150/3150 [==============================] - 8s 3ms/step - loss: 1.2406e-05 - val_loss: 1.4176e-05
# Epoch 169/200
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.2566e-05 - val_loss: 1.4277e-05
# Epoch 170/200
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.2102e-05 - val_loss: 1.4329e-05
# Epoch 171/200
# 3136/3150 [============================>.] - ETA: 0s - loss: 1.0695e-05
# Epoch 00171: ReduceLROnPlateau reducing learning rate to 7.836416443751659e-07.
# 3150/3150 [==============================] - 8s 3ms/step - loss: 1.0650e-05 - val_loss: 1.4268e-05
# Epoch 172/200
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.1919e-05 - val_loss: 1.4328e-05
# Epoch 173/200
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.2056e-05 - val_loss: 1.4354e-05
# Epoch 174/200
# 3150/3150 [==============================] - 8s 3ms/step - loss: 1.0406e-05 - val_loss: 1.4342e-05
# Epoch 175/200
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.2442e-05 - val_loss: 1.4360e-05
# Epoch 176/200
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1.0644e-05 - val_loss: 1.4362e-05
# Epoch 177/200
# 3150/3150 [==============================] - 8s 2ms/step - loss: 1
ochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='best')
plt.show()

# %% [markdown]
# # 5. Generate predictions using the model

# %%
model.load_weights("best_model.h5")
predictions = model.predict([X_temporal_test])

# %%
display_limit = 30
for inputs, pred_cases, exp_cases in zip(X_temporal_test,predictions[:display_limit], Y_cases_test[:display_limit]):
    print("================================================")
    print(inputs)
    print("Expected infectious rate:", exp_cases)
    print("Prediction:", pred_cases)
# Out:
# ================================================
# [[1.8364731e-09 9.8993891e-01]
#  [3.8005674e-09 9.8993891e-01]
#  [3.5155321e-09 9.8993891e-01]
#  [2.7335190e-09 9.8993891e-01]
#  [1.9542401e-09 9.8993891e-01]
#  [1.3394365e-09 9.8993891e-01]
#  [4.4770648e-10 9.8993891e-01]
#  [4.0669401e-10 9.8993891e-01]
#  [2.8807912e-10 9.8993891e-01]
#  [9.2158906e-11 9.8993891e-01]
#  [8.3803534e-11 9.8993891e-01]
#  [6.6407581e-11 9.8993891e-01]
#  [4.1781658e-11 9.8993891e-01]
#  [8.8053774e-12 9.8993891e-01]
#  [1.4573450e-11 9.8993891e-01]
#  [1.0859843e-11 9.8993891e-01]
#  [4.4695068e-12 9.8993891e-01]
#  [2.9097419e-12 9.8993891e-01]
#  [1.4999713e-12 9.8993891e-01]
#  [9.2597674e-13 9.8993891e-01]]
# Expected infectious rate: [4.8432346e-13 2.6817621e-13 1.4687825e-13 7.9554120e-14 4.2603860e-14
#  2.2554187e-14 1.1800645e-14]
# Prediction: [-4.1647813e-06 -2.3992126e-05 -3.8320341e-05 -8.3306804e-05
#  -3.3240860e-05 -5.1160106e-03 -7.9153477e-05]
# ================================================
# [[0.00475443 0.9896052 ]
#  [0.00499305 0.98898214]
#  [0.00556189 0.98802376]
#  [0.00596226 0.98722994]
#  [0.00605154 0.98674434]
#  [0.00508791 0.9873101 ]
#  [0.00506264 0.98693717]
#  [0.00453467 0.9870678 ]
#  [0.00515033 0.986057  ]
#  [0.00534728 0.98546827]
#  [0.00331192 0.9871165 ]
#  [0.00404321 0.98600394]
#  [0.0019863  0.9876898 ]
#  [0.00355674 0.9857594 ]
#  [0.00297485 0.98599327]
#  [0.00348037 0.98515254]
#  [0.00169164 0.98661953]
#  [0.00265753 0.98534584]
#  [0.00203569 0.9856743 ]
#  [0.00183958 0.9855918 ]]
# Expected infectious rate: [0.0019411  0.0017505  0.00157298 0.00140833 0.00125627 0.00111642
#  0.00098837]
# Prediction: [ 1.8343027e-03  1.4189081e-03  1.2635738e-03  7.2261225e-04
#   8.8813622e-04 -5.1765363e-03  4.0207058e-05]
# ================================================
# [[4.2512972e-04 9.9950027e-01]
#  [9.6004020e-04 9.9894714e-01]
#  [1.2888421e-03 9.9859679e-01]
#  [1.8627783e-03 9.9799734e-01]
#  [2.1515114e-03 9.9767858e-01]
#  [8.8145258e-04 9.9891335e-01]
#  [1.8551622e-03 9.9789828e-01]
#  [1.9475886e-03 9.9775761e-01]
#  [3.3058773e-03 9.9634308e-01]
#  [3.3321122e-03 9.9625152e-01]
#  [3.4637726e-03 9.9604422e-01]
#  [2.5453053e-03 9.9687535e-01]
#  [5.2400162e-03 9.9408126e-01]
#  [3.0895341e-03 9.9611908e-01]
#  [3.7654904e-03 9.9531579e-01]
#  [4.2954544e-03 9.9464214e-01]
#  [5.3227181e-03 9.9345326e-01]
#  [5.4776953e-03 9.9311697e-01]
#  [2.0039177e-03 9.9785078e-01]
#  [3.2576285e-03 9.9655712e-01]
#  [4.1552093e-03 9.9560970e-01]
#  [4.8898738e-03 9.9481475e-01]
#  [6.9108782e-03 9.9272108e-01]
#  [4.3291785e-03 9.9521548e-01]
#  [4.9692309e-03 9.9447083e-01]
#  [6.7229499e-03 9.9259222e-01]
#  [7.4516977e-03 9.9171472e-01]
#  [7.6763313e-03 9.9131352e-01]
#  [7.8325756e-03 9.9094826e-01]]
# Expected infectious rate: [0.00907722 0.0096842  0.0103152  0.01096921 0.01164492 0.01234073
#  0.01305475]
# Prediction: [ 0.01015313  0.01025028  0.01009391  0.01069795  0.01114765 -0.00543599
#   0.01106293]
# ================================================
# [[4.0385488e-04 9.9955416e-01]
#  [5.0191773e-04 9.9944752e-01]
#  [5.1055901e-04 9.9942917e-01]
#  [5.5911706e-04 9.9936956e-01]
#  [5.3578318e-04 9.9938035e-01]
#  [3.8128856e-04 9.9952078e-01]
#  [1.0496684e-03 9.9883658e-01]
#  [7.5803342e-04 9.9911046e-01]
#  [1.1388854e-03 9.9870974e-01]
#  [9.6342247e-04 9.9886310e-01]
#  [9.7676797e-04 9.9882519e-01]
#  [9.4902067e-04 9.9882573e-01]
#  [1.2978431e-03 9.9844754e-01]
#  [8.9163962e-04 9.9882215e-01]
#  [1.2202384e-03 9.9845964e-01]
#  [9.1349799e-04 9.9873018e-01]
#  [1.2918573e-03 9.9831313e-01]
#  [1.2701389e-03 9.9829370e-01]
#  [6.2907726e-04 9.9889112e-01]
#  [1.2354027e-03 9.9823862e-01]]
# Expected infectious rate: [0.0010252  0.00101547 0.00100378 0.00099015 0.00097463 0.00095726
#  0.00093812]
# Prediction: [ 0.001219    0.00113057  0.00089469  0.00055895  0.00101702 -0.00516552
#   0.00072362]
# ================================================
# [[1.3569542e-05 9.9724621e-01]
#  [4.7027088e-06 9.9725223e-01]
#  [1.3339162e-05 9.9724120e-01]
#  [7.0414480e-06 9.9724555e-01]
#  [6.2506770e-06 9.9724472e-01]
#  [5.3290564e-06 9.9724430e-01]
#  [2.4657568e-06 9.9724615e-01]
#  [1.8583332e-06 9.9724585e-01]
#  [2.2912950e-06 9.9724472e-01]
#  [1.8804133e-06 9.9724460e-01]
#  [1.5256785e-06 9.9724454e-01]
#  [1.2370248e-06 9.9724448e-01]
#  [8.1824868e-07 9.9724460e-01]
#  [7.9780534e-07 9.9724442e-01]
#  [3.7164210e-07 9.9724466e-01]
#  [3.6955282e-07 9.9724454e-01]
#  [2.6074318e-07 9.9724454e-01]
#  [1.4233544e-07 9.9724460e-01]
#  [1.4290347e-07 9.9724454e-01]
#  [1.4178414e-07 9.9724454e-01]]
# Expected infectious rate: [7.9068414e-08 5.7043462e-08 4.0878735e-08 2.9096027e-08 2.0566944e-08
#  1.4436440e-08 1.0061395e-08]
# Prediction: [ 7.1856193e-05 -3.9058273e-06 -2.1321746e-05 -6.1447266e-05
#  -1.2010615e-05 -5.1251706e-03 -4.5036526e-05]
