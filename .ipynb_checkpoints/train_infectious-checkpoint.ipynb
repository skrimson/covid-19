# %%
import numpy as np
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import os
import tensorflow as tf
from tqdm import tqdm
import requests
import json
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_log_error

from datetime import datetime
from datetime import timedelta

from tensorflow.keras import layers
from tensorflow.keras import Input
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()


for dirname, _, filenames in os.walk('./input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ./input/covid19countryinfo.csv
# ./input/SIR_data.csv
# ./input/states-daily.csv
# ./input/covid19-deepscore.csv
# ./input/population_data.csv
# ./input/full-list-total-tests-for-covid-19.csv
# ./input/country_codes.csv
# ./input/enriched_covid_19_week_2.csv
# ./input/covid19-global-forecasting-week-3/test.csv
# ./input/covid19-global-forecasting-week-3/submission.csv
# ./input/covid19-global-forecasting-week-3/train.csv
# ./input/korea/SeoulFloating.csv
# ./input/korea/TimeAge.csv
# ./input/korea/SearchTrend.csv
# ./input/korea/TimeProvince.csv
# ./input/korea/Weather.csv
# ./input/korea/PatientRoute.csv
# ./input/korea/PatientInfo.csv
# ./input/korea/Region.csv
# ./input/korea/TimeGender.csv
# ./input/korea/Case.csv
# ./input/korea/Time.csv
# ./input/covid19-global-forecasting-week-2/test.csv
# ./input/covid19-global-forecasting-week-2/submission.csv
# ./input/covid19-global-forecasting-week-2/train.csv
# ./input/covidAPI/ESP.json
# ./input/covidAPI/ICL.json
# ./input/covidAPI/CHN.json
# ./input/covidAPI/FRA.json
# ./input/covidAPI/THA.json
# ./input/covidAPI/DNK.json
# ./input/covidAPI/DEU.json
# ./input/covidAPI/KOR.json
# ./input/covidAPI/TWN.json
# ./input/covidAPI/ISL.json
# ./input/covidAPI/ITA.json
# ./input/.ipynb_checkpoints/SIR_data-checkpoint.csv
# ./input/.ipynb_checkpoints/covid19-deepscore-checkpoint.csv

# %%
train_df = pd.read_csv("./input/SIR_data.csv")
train_df.tail()
# Out:
#         Unnamed: 0           Code        Date     confirmed  confirmed_noise  \
# 119995         155  SIR-large-249  2020-07-05  6.813406e-09     8.345405e-09
# 119996         156  SIR-large-249  2020-07-06  3.576303e-09     3.202185e-09
# 119997         157  SIR-large-249  2020-07-07  1.854928e-09     1.278237e-09
# 119998         158  SIR-large-249  2020-07-08  9.504876e-10     1.032974e-09
# 119999         159  SIR-large-249  2020-07-09  4.810533e-10     6.917720e-10
#
#         infectious_noise_rate  infectious_rate      removed  removed_noise  \
# 119995           4.172703e-14     3.406703e-14  1744.099053    1744.099053
# 119996           1.601093e-14     1.788151e-14  1744.099053    1744.099053
# 119997           6.391185e-15     9.274641e-15  1744.099053    1744.099053
# 119998           5.164868e-15     4.752438e-15  1744.099053    1744.099053
# 119999           3.458860e-15     2.405266e-15  1744.099053    1744.099053
#
#         removed_noise_rate  removed_rate    susceptible  susceptible_noise  \
# 119995             0.00872       0.00872  198255.900947      198255.900947
# 119996             0.00872       0.00872  198255.900947      198255.900947
# 119997             0.00872       0.00872  198255.900947      198255.900947
# 119998             0.00872       0.00872  198255.900947      198255.900947
# 119999             0.00872       0.00872  198255.900947      198255.900947
#
#         susceptible_noise_rate  susceptible_rate
# 119995                 0.99128           0.99128
# 119996                 0.99128           0.99128
# 119997                 0.99128           0.99128
# 119998                 0.99128           0.99128
# 119999                 0.99128           0.99128

# %%
days_in_sequence = 21
output_days = 7

sequence_length = days_in_sequence - 1
training_percentage = 0.9
temp_dim = 2 # infectious and suspicious

# %%
#temporal input branch
temporal_input_layer = Input(shape=(sequence_length,temp_dim))
main_rnn_layer = layers.LSTM(64, return_sequences=True, recurrent_dropout=0.2)(temporal_input_layer)

#cases output branch
rnn_c = layers.LSTM(32)(main_rnn_layer)
# merge_c = layers.Concatenate(axis=-1)([rnn_c,demographic_dropout])
dense_c = layers.Dense(16)(rnn_c)
dropout_c = layers.Dropout(0.2)(dense_c)
output_c = layers.Dense(7)(dropout_c) #activation=layers.LeakyReLU(alpha=0.1)
cases = layers.LeakyReLU(alpha=0.1,name="infectious")(output_c)

model = Model([temporal_input_layer], [cases])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 20, 2)             0
# _________________________________________________________________
# lstm (LSTM)                  (None, 20, 64)            17152
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                12416
# _________________________________________________________________
# dense (Dense)                (None, 16)                528
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 119
# _________________________________________________________________
# infectious (LeakyReLU)       (None, 7)                 0
# =================================================================
# Total params: 30,215
# Trainable params: 30,215
# Non-trainable params: 0
# _________________________________________________________________

# %%
callbacks = [ReduceLROnPlateau(monitor='val_loss', verbose=1, factor=0.6), #patience=4  #EarlyStopping(monitor='val_loss', patience=20)
             ModelCheckpoint(filepath='best_infectious_model.h5', monitor='val_loss', save_best_only=True)]
model.compile(loss=[tf.keras.losses.mean_squared_logarithmic_error], optimizer="adam")

# %%
# Creating train input from DataFrames No Noise
# train_country = ["KOR", "TWA", "THA", "ITA", "ISL", "DNK"]
# train_df = train_df.query("Code in {}".format(train_country))

trend_list = []

# for code in train_df.Code.unique():
for i in range(250):
    code = "SIR-small-{}".format(i)
    country_df = train_df.query(f"Code=='{code}'")
    # Added a quick hack to double the number of sequences
    # Warning: This will later create a minor leakage from the training set into the validation set.
    for i in range(0,len(country_df),int(days_in_sequence/2)):
        if i+days_in_sequence<=len(country_df):
            
            #prepare rate inputs, use rates with noise
            infectious_rate_trend = [float(x) for x in country_df[i:i+days_in_sequence-1].infectious_rate]
            susceptible_rate_trend = [float(x) for x in country_df[i:i+days_in_sequence-1].susceptible_rate] 

            #prepare outputs, use original rates
            expected_infectious_rate = [float(x) for x in country_df.iloc[i+days_in_sequence-1:i+days_in_sequence-1+output_days].infectious_rate]

            trend_list.append({ "infectious_rate_trend":infectious_rate_trend,
                                "susceptible_rate_trend":susceptible_rate_trend,
                                "expected_infectious_rate":expected_infectious_rate})
trend_df = pd.DataFrame(trend_list)

trend_df["temporal_inputs"] = [np.asarray([trends["infectious_rate_trend"], trends["susceptible_rate_trend"]]) for idx,trends in trend_df.iterrows()]

trend_df = shuffle(trend_df)

training_item_count = int(len(trend_df)*training_percentage)
validation_item_count = len(trend_df)-int(len(trend_df)*training_percentage)
training_df = trend_df[:training_item_count]
validation_df = trend_df[training_item_count:]

X_temporal_train = np.asarray(np.transpose(np.reshape(np.asarray([np.asarray(x) for x in training_df["temporal_inputs"].values]),(training_item_count,temp_dim,sequence_length)),(0,2,1) )).astype(np.float32)
Y_cases_train = np.asarray([np.asarray(x) for x in training_df["expected_infectious_rate"]]).astype(np.float32)

X_temporal_test = np.asarray(np.transpose(np.reshape(np.asarray([np.asarray(x) for x in validation_df["temporal_inputs"]]),(validation_item_count,temp_dim,sequence_length)),(0,2,1)) ).astype(np.float32)
Y_cases_test = np.asarray([np.asarray(x) for x in validation_df["expected_infectious_rate"]]).astype(np.float32)

# %%
history = model.fit([X_temporal_train], [Y_cases_train], 
          epochs = 50, 
          batch_size = 16, 
          validation_data=([X_temporal_test],  [Y_cases_test]), 
          callbacks=callbacks)
loss = history.history['loss']
val_loss = history.history['val_loss']
# Out:
# Train on 3150 samples, validate on 350 samples
# Epoch 1/50
# 3150/3150 [==============================] - 12s 4ms/step - loss: 2.0541e-04 - val_loss: 1.3659e-04
# Epoch 2/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 1.9286e-04 - val_loss: 1.3659e-04
# Epoch 3/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 1.9340e-04 - val_loss: 1.3659e-04
# Epoch 4/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 1.9280e-04 - val_loss: 1.3659e-04
# Epoch 5/50
# 3150/3150 [==============================] - 8s 3ms/step - loss: 1.9269e-04 - val_loss: 1.3659e-04
# Epoch 6/50
# 3150/3150 [==============================] - 8s 3ms/step - loss: 1.8281e-04 - val_loss: 1.1300e-04
# Epoch 7/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 1.5011e-04 - val_loss: 8.8817e-05
# Epoch 8/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 1.3449e-04 - val_loss: 8.9006e-05
# Epoch 9/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 8.8406e-05 - val_loss: 4.4686e-05
# Epoch 10/50
# 3150/3150 [==============================] - 8s 3ms/step - loss: 7.5291e-05 - val_loss: 6.7166e-05
# Epoch 11/50
# 3136/3150 [============================>.] - ETA: 0s - loss: 7.4779e-05
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0006000000284984708.
# 3150/3150 [==============================] - 8s 3ms/step - loss: 7.4722e-05 - val_loss: 4.2709e-05
# Epoch 12/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 6.4468e-05 - val_loss: 4.0915e-05
# Epoch 13/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 6.3738e-05 - val_loss: 4.2936e-05
# Epoch 14/50
# 3150/3150 [==============================] - 8s 3ms/step - loss: 6.4377e-05 - val_loss: 4.5253e-05
# Epoch 15/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 6.3103e-05 - val_loss: 3.9645e-05
# Epoch 16/50
# 3150/3150 [==============================] - 8s 2ms/step - loss: 6.2353e-05 - val_loss: 4.0557e-05
# Epoch 17/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 6.2619e-05 - val_loss: 4.0764e-05
# Epoch 18/50
# 3150/3150 [==============================] - 10s 3ms/step - loss: 6.1957e-05 - val_loss: 3.9670e-05
# Epoch 19/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 6.1881e-05 - val_loss: 3.9267e-05
# Epoch 20/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 6.1882e-05 - val_loss: 3.9818e-05
# Epoch 21/50
# 3136/3150 [============================>.] - ETA: 0s - loss: 6.0524e-05
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0003600000170990825.
# 3150/3150 [==============================] - 10s 3ms/step - loss: 6.0435e-05 - val_loss: 3.9181e-05
# Epoch 22/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 6.0155e-05 - val_loss: 3.8633e-05
# Epoch 23/50
# 3150/3150 [==============================] - 10s 3ms/step - loss: 5.9947e-05 - val_loss: 3.9663e-05
# Epoch 24/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.9892e-05 - val_loss: 3.9287e-05
# Epoch 25/50
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.8632e-05 - val_loss: 3.9280e-05
# Epoch 26/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.9252e-05 - val_loss: 3.9262e-05
# Epoch 27/50
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.8810e-05 - val_loss: 3.8654e-05
# Epoch 28/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.9060e-05 - val_loss: 3.8793e-05
# Epoch 29/50
# 3150/3150 [==============================] - 10s 3ms/step - loss: 5.8948e-05 - val_loss: 3.9261e-05
# Epoch 30/50
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.8815e-05 - val_loss: 3.8679e-05
# Epoch 31/50
# 3120/3150 [============================>.] - ETA: 0s - loss: 5.8784e-05
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.00021600000327453016.
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.8615e-05 - val_loss: 4.0061e-05
# Epoch 32/50
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.8223e-05 - val_loss: 4.0454e-05
# Epoch 33/50
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.8995e-05 - val_loss: 3.8794e-05
# Epoch 34/50
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.9020e-05 - val_loss: 3.8979e-05
# Epoch 35/50
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.8404e-05 - val_loss: 3.8776e-05
# Epoch 36/50
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.8799e-05 - val_loss: 4.0108e-05
# Epoch 37/50
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.9601e-05 - val_loss: 3.8445e-05
# Epoch 38/50
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.8687e-05 - val_loss: 3.8607e-05
# Epoch 39/50
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.8934e-05 - val_loss: 3.8499e-05
# Epoch 40/50
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.8534e-05 - val_loss: 3.8703e-05
# Epoch 41/50
# 3120/3150 [============================>.] - ETA: 0s - loss: 5.9568e-05
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.00012960000021848827.
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.9056e-05 - val_loss: 3.8793e-05
# Epoch 42/50
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.7576e-05 - val_loss: 3.8610e-05
# Epoch 43/50
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.7907e-05 - val_loss: 3.8382e-05
# Epoch 44/50
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.8043e-05 - val_loss: 3.8550e-05
# Epoch 45/50
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.7910e-05 - val_loss: 3.9061e-05
# Epoch 46/50
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.7976e-05 - val_loss: 3.8655e-05
# Epoch 47/50
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.7664e-05 - val_loss: 3.8637e-05
# Epoch 48/50
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.7569e-05 - val_loss: 3.8671e-05
# Epoch 49/50
# 3150/3150 [==============================] - 10s 3ms/step - loss: 5.7987e-05 - val_loss: 3.8412e-05
# Epoch 50/50
# 3150/3150 [==============================] - 10s 3ms/step - loss: 5.7354e-05 - val_loss: 3.8454e-05

# %%
# Creating train input from DataFrames Small Noise
# train_country = ["KOR", "TWA", "THA", "ITA", "ISL", "DNK"]
# train_df = train_df.query("Code in {}".format(train_country))
days_in_sequence = 21
output_days = 7

trend_list = []

# for code in train_df.Code.unique():
for i in range(250):
    code = "SIR-small-{}".format(i)
    country_df = train_df.query(f"Code=='{code}'")
    # Added a quick hack to double the number of sequences
    # Warning: This will later create a minor leakage from the training set into the validation set.
    for i in range(0,len(country_df),int(days_in_sequence/2)):
        if i+days_in_sequence<=len(country_df):
            
            #prepare rate inputs, use rates with noise
            infectious_rate_trend = [float(x) for x in country_df[i:i+days_in_sequence-1].infectious_noise_rate]
            susceptible_rate_trend = [float(x) for x in country_df[i:i+days_in_sequence-1].susceptible_noise_rate] 

            #prepare outputs, use original rates
            expected_infectious_rate = [float(x) for x in country_df.iloc[i+days_in_sequence-1:i+days_in_sequence-1+output_days].infectious_rate]
            
            trend_list.append({ "infectious_rate_trend":infectious_rate_trend,
                                "susceptible_rate_trend":susceptible_rate_trend,
                                "expected_infectious_rate":expected_infectious_rate})
trend_df = pd.DataFrame(trend_list)

trend_df["temporal_inputs"] = [np.asarray([trends["infectious_rate_trend"], trends["susceptible_rate_trend"]]) for idx,trends in trend_df.iterrows()]

trend_df = shuffle(trend_df)

training_item_count = int(len(trend_df)*training_percentage)
validation_item_count = len(trend_df)-int(len(trend_df)*training_percentage)
training_df = trend_df[:training_item_count]
validation_df = trend_df[training_item_count:]

X_temporal_train = np.asarray(np.transpose(np.reshape(np.asarray([np.asarray(x) for x in training_df["temporal_inputs"].values]),(training_item_count,temp_dim,sequence_length)),(0,2,1) )).astype(np.float32)
Y_cases_train = np.asarray([np.asarray(x) for x in training_df["expected_infectious_rate"]]).astype(np.float32)

X_temporal_test = np.asarray(np.transpose(np.reshape(np.asarray([np.asarray(x) for x in validation_df["temporal_inputs"]]),(validation_item_count,temp_dim,sequence_length)),(0,2,1)) ).astype(np.float32)
Y_cases_test = np.asarray([np.asarray(x) for x in validation_df["expected_infectious_rate"]]).astype(np.float32)

# %%
history = model.fit([X_temporal_train], [Y_cases_train], 
          initial_epoch=50,
          epochs = 100,  
          batch_size = 16, 
          validation_data=([X_temporal_test],  [Y_cases_test]), 
          callbacks=callbacks)
loss.extend(history.history['loss'])
val_loss.extend(history.history['val_loss'])
# Out:
# Train on 3150 samples, validate on 350 samples
# Epoch 51/100
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.6499e-05 - val_loss: 5.4426e-05
# Epoch 52/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.6675e-05 - val_loss: 5.4103e-05
# Epoch 53/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.7387e-05 - val_loss: 5.4100e-05
# Epoch 54/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.6722e-05 - val_loss: 5.4958e-05
# Epoch 55/100
# 3150/3150 [==============================] - 10s 3ms/step - loss: 5.6398e-05 - val_loss: 5.4067e-05
# Epoch 56/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.5788e-05 - val_loss: 5.3990e-05
# Epoch 57/100
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.6742e-05 - val_loss: 5.3999e-05
# Epoch 58/100
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.6079e-05 - val_loss: 5.3993e-05
# Epoch 59/100
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.6824e-05 - val_loss: 5.3962e-05
# Epoch 60/100
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.6836e-05 - val_loss: 5.3779e-05
# Epoch 61/100
# 3136/3150 [============================>.] - ETA: 0s - loss: 5.5645e-05
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 7.775999838486313e-05.
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.6254e-05 - val_loss: 5.4398e-05
# Epoch 62/100
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.6203e-05 - val_loss: 5.4056e-05
# Epoch 63/100
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.6486e-05 - val_loss: 5.3966e-05
# Epoch 64/100
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.6260e-05 - val_loss: 5.4265e-05
# Epoch 65/100
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.6035e-05 - val_loss: 5.3903e-05
# Epoch 66/100
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.5645e-05 - val_loss: 5.4034e-05
# Epoch 67/100
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.6233e-05 - val_loss: 5.4531e-05
# Epoch 68/100
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.5924e-05 - val_loss: 5.3975e-05
# Epoch 69/100
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.6111e-05 - val_loss: 5.4034e-05
# Epoch 70/100
# 3150/3150 [==============================] - 12s 4ms/step - loss: 5.5811e-05 - val_loss: 5.3852e-05
# Epoch 71/100
# 3136/3150 [============================>.] - ETA: 0s - loss: 5.6883e-05
# Epoch 00071: ReduceLROnPlateau reducing learning rate to 4.6655999904032795e-05.
# 3150/3150 [==============================] - 10s 3ms/step - loss: 5.6738e-05 - val_loss: 5.3990e-05
# Epoch 72/100
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.5644e-05 - val_loss: 5.3884e-05
# Epoch 73/100
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.6179e-05 - val_loss: 5.4164e-05
# Epoch 74/100
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.6501e-05 - val_loss: 5.4229e-05
# Epoch 75/100
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.6712e-05 - val_loss: 5.4032e-05
# Epoch 76/100
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.5720e-05 - val_loss: 5.3759e-05
# Epoch 77/100
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.5673e-05 - val_loss: 5.3947e-05
# Epoch 78/100
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.6466e-05 - val_loss: 5.3941e-05
# Epoch 79/100
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.5886e-05 - val_loss: 5.4044e-05
# Epoch 80/100
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.5721e-05 - val_loss: 5.4168e-05
# Epoch 81/100
# 3120/3150 [============================>.] - ETA: 0s - loss: 5.5907e-05
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 2.799360081553459e-05.
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.6162e-05 - val_loss: 5.3889e-05
# Epoch 82/100
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.6395e-05 - val_loss: 5.4068e-05
# Epoch 83/100
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.5739e-05 - val_loss: 5.3921e-05
# Epoch 84/100
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.5787e-05 - val_loss: 5.3766e-05
# Epoch 85/100
# 3150/3150 [==============================] - 8s 2ms/step - loss: 5.6110e-05 - val_loss: 5.3785e-05
# Epoch 86/100
# 3150/3150 [==============================] - 11s 3ms/step - loss: 5.6181e-05 - val_loss: 5.3791e-05
# Epoch 87/100
# 3150/3150 [==============================] - 11s 4ms/step - loss: 5.5917e-05 - val_loss: 5.3780e-05
# Epoch 88/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.5851e-05 - val_loss: 5.3906e-05
# Epoch 89/100
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.6100e-05 - val_loss: 5.3772e-05
# Epoch 90/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.5276e-05 - val_loss: 5.3796e-05
# Epoch 91/100
# 3120/3150 [============================>.] - ETA: 0s - loss: 5.4961e-05
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 1.6796160707599483e-05.
# 3150/3150 [==============================] - 8s 3ms/step - loss: 5.6712e-05 - val_loss: 5.3792e-05
# Epoch 92/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.6021e-05 - val_loss: 5.3820e-05
# Epoch 93/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.5612e-05 - val_loss: 5.3778e-05
# Epoch 94/100
# 3150/3150 [==============================] - 9s 3ms/step - loss: 5.5655e-05 - val_loss: 5.3828e-05
# Epoch 95/100
# 3150/3150 [==============================] - 10s 3ms/step - loss: 5.6890e-05 - val_loss: 5.3785e-05
# Epoch 96/100
# 3150/3150 [==============================] - 11s 4ms/step - loss: 5.6163e-05 - val_loss: 5.3802e-05
# Epoch 97/100
# 3150/3150 [==============================] - 10s 3ms/step - loss: 5.6188e-05 - val_loss: 5.3865e-05
# Epoch 98/100
# 3150/3150 [==============================] - 10s 3ms/step - loss: 5.6773e-05 - val_loss: 5.3959e-05
# Epoch 99/100
# 3150/3150 [==============================] - 10s 3ms/step - loss: 5.6180e-05 - val_loss: 5.3783e-05
# Epoch 100/100
# 3150/3150 [==============================] - 10s 3ms/step - loss: 5.5961e-05 - val_loss: 5.3774e-05

# %%
# Create middle noise data
days_in_sequence = 21
output_days = 7

trend_list = []

# for code in train_df.Code.unique():
for i in range(250):
    code = "SIR-middle-{}".format(i)
    country_df = train_df.query(f"Code=='{code}'")
    # Added a quick hack to double the number of sequences
    # Warning: This will later create a minor leakage from the training set into the validation set.
    for i in range(0,len(country_df),int(days_in_sequence/2)):
        if i+days_in_sequence<=len(country_df):
            
            #prepare rate inputs, use rates with noise
            infectious_rate_trend = [float(x) for x in country_df[i:i+days_in_sequence-1].infectious_noise_rate]
            susceptible_rate_trend = [float(x) for x in country_df[i:i+days_in_sequence-1].susceptible_noise_rate] 

            #prepare outputs, use original rates
            expected_infectious_rate = [float(x) for x in country_df.iloc[i+days_in_sequence-1:i+days_in_sequence-1+output_days].infectious_rate]

            trend_list.append({ "infectious_rate_trend":infectious_rate_trend,
                                "susceptible_rate_trend":susceptible_rate_trend,
                                "expected_infectious_rate":expected_infectious_rate})
trend_df = pd.DataFrame(trend_list)

trend_df["temporal_inputs"] = [np.asarray([trends["infectious_rate_trend"], trends["susceptible_rate_trend"]]) for idx,trends in trend_df.iterrows()]

trend_df = shuffle(trend_df)
print(len(trend_df))
trend_df.head()

training_item_count = int(len(trend_df)*training_percentage)
validation_item_count = len(trend_df)-int(len(trend_df)*training_percentage)
training_df = trend_df[:training_item_count]
validation_df = trend_df[training_item_count:]

X_temporal_train = np.asarray(np.transpose(np.reshape(np.asarray([np.asarray(x) for x in training_df["temporal_inputs"].values]),(training_item_count,temp_dim,sequence_length)),(0,2,1) )).astype(np.float32)
Y_cases_train = np.asarray([np.asarray(x) for x in training_df["expected_infectious_rate"]]).astype(np.float32)

X_temporal_test = np.asarray(np.transpose(np.reshape(np.asarray([np.asarray(x) for x in validation_df["temporal_inputs"]]),(validation_item_count,temp_dim,sequence_length)),(0,2,1)) ).astype(np.float32)
Y_cases_test = np.asarray([np.asarray(x) for x in validation_df["expected_infectious_rate"]]).astype(np.float32)
# Out:
# 3500

# %%
history = model.fit([X_temporal_train], [Y_cases_train],
          initial_epoch=100,
          epochs = 150, 
          batch_size = 16, 
          validation_data=([X_temporal_test],  [Y_cases_test]), 
          callbacks=callbacks)
loss.extend(history.history['loss'])
val_loss.extend(history.history['val_loss'])
# Out:
# Train on 3150 samples, validate on 350 samples
# Epoch 101/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.0676e-05 - val_loss: 2.2559e-05
# Epoch 102/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 3.0720e-05 - val_loss: 2.2763e-05
# Epoch 103/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.0116e-05 - val_loss: 2.2509e-05
# Epoch 104/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 3.0726e-05 - val_loss: 2.2628e-05
# Epoch 105/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.0196e-05 - val_loss: 2.2534e-05
# Epoch 106/150
# 3150/3150 [==============================] - 10s 3ms/step - loss: 3.0498e-05 - val_loss: 2.2570e-05
# Epoch 107/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.0412e-05 - val_loss: 2.2655e-05
# Epoch 108/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.0165e-05 - val_loss: 2.2630e-05
# Epoch 109/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 3.0100e-05 - val_loss: 2.2615e-05
# Epoch 110/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 3.0084e-05 - val_loss: 2.2567e-05
# Epoch 111/150
# 3136/3150 [============================>.] - ETA: 0s - loss: 3.0001e-05
# Epoch 00111: ReduceLROnPlateau reducing learning rate to 1.007769642455969e-05.
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.0348e-05 - val_loss: 2.2588e-05
# Epoch 112/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 3.0155e-05 - val_loss: 2.2602e-05
# Epoch 113/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 2.9910e-05 - val_loss: 2.2653e-05
# Epoch 114/150
# 3150/3150 [==============================] - 8s 3ms/step - loss: 3.0169e-05 - val_loss: 2.2633e-05
# Epoch 115/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.0090e-05 - val_loss: 2.2571e-05
# Epoch 116/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.0056e-05 - val_loss: 2.2632e-05
# Epoch 117/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.0008e-05 - val_loss: 2.2615e-05
# Epoch 118/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.0475e-05 - val_loss: 2.2585e-05
# Epoch 119/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.0007e-05 - val_loss: 2.2527e-05
# Epoch 120/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.0081e-05 - val_loss: 2.2676e-05
# Epoch 121/150
# 3120/3150 [============================>.] - ETA: 0s - loss: 3.0135e-05
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 6.046617636457085e-06.
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.9981e-05 - val_loss: 2.2647e-05
# Epoch 122/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.0159e-05 - val_loss: 2.2678e-05
# Epoch 123/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.0001e-05 - val_loss: 2.2757e-05
# Epoch 124/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.9977e-05 - val_loss: 2.2635e-05
# Epoch 125/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.9873e-05 - val_loss: 2.2666e-05
# Epoch 126/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.9793e-05 - val_loss: 2.2691e-05
# Epoch 127/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.9656e-05 - val_loss: 2.2625e-05
# Epoch 128/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.9712e-05 - val_loss: 2.2587e-05
# Epoch 129/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.9831e-05 - val_loss: 2.2707e-05
# Epoch 130/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.9985e-05 - val_loss: 2.2696e-05
# Epoch 131/150
# 3136/3150 [============================>.] - ETA: 0s - loss: 2.9351e-05
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 3.6279706364439334e-06.
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.9581e-05 - val_loss: 2.2676e-05
# Epoch 132/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.0093e-05 - val_loss: 2.2587e-05
# Epoch 133/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.9984e-05 - val_loss: 2.2591e-05
# Epoch 134/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.0100e-05 - val_loss: 2.2572e-05
# Epoch 135/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.9773e-05 - val_loss: 2.2620e-05
# Epoch 136/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.9949e-05 - val_loss: 2.2614e-05
# Epoch 137/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.9822e-05 - val_loss: 2.2716e-05
# Epoch 138/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.9600e-05 - val_loss: 2.2652e-05
# Epoch 139/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.9638e-05 - val_loss: 2.2659e-05
# Epoch 140/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.9649e-05 - val_loss: 2.2651e-05
# Epoch 141/150
# 3136/3150 [============================>.] - ETA: 0s - loss: 2.8945e-05
# Epoch 00141: ReduceLROnPlateau reducing learning rate to 2.1767824364360423e-06.
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.9607e-05 - val_loss: 2.2696e-05
# Epoch 142/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.9703e-05 - val_loss: 2.2713e-05
# Epoch 143/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.9537e-05 - val_loss: 2.2671e-05
# Epoch 144/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.9640e-05 - val_loss: 2.2685e-05
# Epoch 145/150
# 3150/3150 [==============================] - 10s 3ms/step - loss: 3.0024e-05 - val_loss: 2.2680e-05
# Epoch 146/150
# 3150/3150 [==============================] - 10s 3ms/step - loss: 2.9918e-05 - val_loss: 2.2665e-05
# Epoch 147/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 3.0180e-05 - val_loss: 2.2627e-05
# Epoch 148/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.9879e-05 - val_loss: 2.2665e-05
# Epoch 149/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.9870e-05 - val_loss: 2.2656e-05
# Epoch 150/150
# 3150/3150 [==============================] - 9s 3ms/step - loss: 2.9632e-05 - val_loss: 2.2669e-05

# %%
# Create large noise data
days_in_sequence = 21
output_days = 7

trend_list = []

# for code in train_df.Code.unique():
for i in range(250):
    code = "SIR-large-{}".format(i)
    country_df = train_df.query(f"Code=='{code}'")
    # Added a quick hack to double the number of sequences
    # Warning: This will later create a minor leakage from the training set into the validation set.
    for i in range(0,len(country_df),int(days_in_sequence/2)):
        if i+days_in_sequence<=len(country_df):
            
            #prepare rate inputs, use rates with noise
            infectious_rate_trend = [float(x) for x in country_df[i:i+days_in_sequence-1].infectious_noise_rate]
            susceptible_rate_trend = [float(x) for x in country_df[i:i+days_in_sequence-1].susceptible_noise_rate] 

            #prepare outputs, use original rates
            expected_infectious_rate = [float(x) for x in country_df.iloc[i+days_in_sequence-1:i+days_in_sequence-1+output_days].infectious_rate]

            trend_list.append({ "infectious_rate_trend":infectious_rate_trend,
                                "susceptible_rate_trend":susceptible_rate_trend,
                                "expected_infectious_rate":expected_infectious_rate})
trend_df = pd.DataFrame(trend_list)

trend_df["temporal_inputs"] = [np.asarray([trends["infectious_rate_trend"], trends["susceptible_rate_trend"]]) for idx,trends in trend_df.iterrows()]

trend_df = shuffle(trend_df)
print(len(trend_df))
trend_df.head()

training_item_count = int(len(trend_df)*training_percentage)
validation_item_count = len(trend_df)-int(len(trend_df)*training_percentage)
training_df = trend_df[:training_item_count]
validation_df = trend_df[training_item_count:]

X_temporal_train = np.asarray(np.transpose(np.reshape(np.asarray([np.asarray(x) for x in training_df["temporal_inputs"].values]),(training_item_count,temp_dim,sequence_length)),(0,2,1) )).astype(np.float32)
Y_cases_train = np.asarray([np.asarray(x) for x in training_df["expected_infectious_rate"]]).astype(np.float32)

X_temporal_test = np.asarray(np.transpose(np.reshape(np.asarray([np.asarray(x) for x in validation_df["temporal_inputs"]]),(validation_item_count,temp_dim,sequence_length)),(0,2,1)) ).astype(np.float32)
Y_cases_test = np.asarray([np.asarray(x) for x in validation_df["expected_infectious_rate"]]).astype(np.float32)
# Out:
# 3500

# %%
history = model.fit([X_temporal_train], [Y_cases_train],
          initial_epoch=150,
          epochs = 200, 
          batch_size = 16, 
          validation_data=([X_temporal_test],  [Y_cases_test]), 
          callbacks=callbacks)
loss.extend(history.history['loss'])
val_loss.extend(history.history['val_loss'])
# Out:
# Train on 3150 samples, validate on 350 samples
# Epoch 151/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.5978e-05 - val_loss: 6.1307e-05
# Epoch 152/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.5736e-05 - val_loss: 6.1320e-05
# Epoch 153/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6740e-05 - val_loss: 6.1408e-05
# Epoch 154/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6990e-05 - val_loss: 6.1396e-05
# Epoch 155/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6321e-05 - val_loss: 6.1365e-05
# Epoch 156/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6194e-05 - val_loss: 6.1339e-05
# Epoch 157/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.5778e-05 - val_loss: 6.1372e-05
# Epoch 158/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.5612e-05 - val_loss: 6.1352e-05
# Epoch 159/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6599e-05 - val_loss: 6.1271e-05
# Epoch 160/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6143e-05 - val_loss: 6.1200e-05
# Epoch 161/200
# 3120/3150 [============================>.] - ETA: 0s - loss: 4.6286e-05
# Epoch 00161: ReduceLROnPlateau reducing learning rate to 1.3060694072919432e-06.
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6106e-05 - val_loss: 6.1133e-05
# Epoch 162/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6848e-05 - val_loss: 6.1130e-05
# Epoch 163/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.5915e-05 - val_loss: 6.1146e-05
# Epoch 164/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.5754e-05 - val_loss: 6.1165e-05
# Epoch 165/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.5929e-05 - val_loss: 6.1184e-05
# Epoch 166/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6457e-05 - val_loss: 6.1144e-05
# Epoch 167/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.5844e-05 - val_loss: 6.1149e-05
# Epoch 168/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.7025e-05 - val_loss: 6.1117e-05
# Epoch 169/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6018e-05 - val_loss: 6.1117e-05
# Epoch 170/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6084e-05 - val_loss: 6.1124e-05
# Epoch 171/200
# 3136/3150 [============================>.] - ETA: 0s - loss: 4.6202e-05
# Epoch 00171: ReduceLROnPlateau reducing learning rate to 7.836416443751659e-07.
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6137e-05 - val_loss: 6.1176e-05
# Epoch 172/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6002e-05 - val_loss: 6.1158e-05
# Epoch 173/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6239e-05 - val_loss: 6.1151e-05
# Epoch 174/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6841e-05 - val_loss: 6.1144e-05
# Epoch 175/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.7475e-05 - val_loss: 6.1144e-05
# Epoch 176/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6300e-05 - val_loss: 6.1162e-05
# Epoch 177/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.7139e-05 - val_loss: 6.1147e-05
# Epoch 178/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.5854e-05 - val_loss: 6.1142e-05
# Epoch 179/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6963e-05 - val_loss: 6.1119e-05
# Epoch 180/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6335e-05 - val_loss: 6.1102e-05
# Epoch 181/200
# 3136/3150 [============================>.] - ETA: 0s - loss: 4.6897e-05
# Epoch 00181: ReduceLROnPlateau reducing learning rate to 4.701850002675201e-07.
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6729e-05 - val_loss: 6.1093e-05
# Epoch 182/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.7272e-05 - val_loss: 6.1089e-05
# Epoch 183/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.7280e-05 - val_loss: 6.1085e-05
# Epoch 184/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6300e-05 - val_loss: 6.1076e-05
# Epoch 185/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6660e-05 - val_loss: 6.1084e-05
# Epoch 186/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6063e-05 - val_loss: 6.1076e-05
# Epoch 187/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6571e-05 - val_loss: 6.1087e-05
# Epoch 188/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.7126e-05 - val_loss: 6.1096e-05
# Epoch 189/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.5828e-05 - val_loss: 6.1106e-05
# Epoch 190/200
# 3150/3150 [==============================] - 10s 3ms/step - loss: 4.6781e-05 - val_loss: 6.1115e-05
# Epoch 191/200
# 3136/3150 [============================>.] - ETA: 0s - loss: 4.7825e-05
# Epoch 00191: ReduceLROnPlateau reducing learning rate to 2.8211100016051206e-07.
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.7723e-05 - val_loss: 6.1107e-05
# Epoch 192/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.5453e-05 - val_loss: 6.1103e-05
# Epoch 193/200
# 3150/3150 [==============================] - 10s 3ms/step - loss: 4.6221e-05 - val_loss: 6.1105e-05
# Epoch 194/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.5889e-05 - val_loss: 6.1110e-05
# Epoch 195/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.5280e-05 - val_loss: 6.1115e-05
# Epoch 196/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.5733e-05 - val_loss: 6.1114e-05
# Epoch 197/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.6130e-05 - val_loss: 6.1121e-05
# Epoch 198/200
# 3150/3150 [==============================] - 9s 3ms/step - loss: 4.7771e-05 - val_loss: 6.1121e-05
# Epoch 199/200
# 3150/3150 [==============================] - 10s 3ms/step - loss: 4.5701e-05 - val_loss: 6.1114e-05
# Epoch 200/200
# 3150/3150 [==============================] - 10s 3ms/step - loss: 4.5841e-05 - val_loss: 6.1121e-05

# %% [markdown]
# # 4. Performance during training

# %%
plt.plot(loss)
plt.plot(val_loss)
plt.title('Loss over epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='best')
plt.show()

# %% [markdown]
# # 5. Generate predictions using the model

# %%
model.load_weights("best_model.h5")
predictions = model.predict([X_temporal_test])

# %%
display_limit = 30
for inputs, pred_cases, exp_cases in zip(X_temporal_test,predictions[:display_limit], Y_cases_test[:display_limit]):
    print("================================================")
    print(inputs)
    print("Expected infectious rate:", exp_cases)
    print("Prediction:", pred_cases)
# Out:
# ================================================
# [[6.9935829e-04 9.9924946e-01]
#  [1.0176707e-03 9.9891913e-01]
#  [6.4181967e-04 9.9928063e-01]
#  [9.5796428e-04 9.9894756e-01]
#  [1.0181443e-03 9.9886739e-01]
#  [9.4494352e-04 9.9891704e-01]
